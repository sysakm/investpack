# %%
# !pip freeze > requirements.txt

# %%
# !pip install openbb --upgrade
# Out:
# Requirement already satisfied: openbb in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (2.1.0)
# Collecting openbb
#   Downloading openbb-2.2.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: tokenterminal<2.0.0,>=1.0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.0.1)
# Requirement already satisfied: fredapi<0.5.0,>=0.4.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.4.3)
# Requirement already satisfied: praw<8.0.0,>=7.1.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (7.6.1)
# Requirement already satisfied: python-coinmarketcap<0.3,>=0.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.2)
# Requirement already satisfied: python-dotenv<0.20.0,>=0.19.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.19.2)
# Requirement already satisfied: holidays<0.15.0,>=0.14.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.14.2)
# Requirement already satisfied: detecta<0.0.6,>=0.0.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.0.5)
# Requirement already satisfied: pycoingecko<3.0.0,>=2.2.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.3.0)
# Requirement already satisfied: FundamentalAnalysis<0.3.0,>=0.2.6 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.2.14)
# Requirement already satisfied: tradingview-ta<4.0.0,>=3.2.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.3.0)
# Requirement already satisfied: financedatabase==1.0.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.0.2)
# Requirement already satisfied: linearmodels<5.0,>=4.25 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (4.27)
# Requirement already satisfied: jsonschema<4.0.0,>=3.2.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.2.0)
# Requirement already satisfied: finviz<2.0.0,>=1.3.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.4.4)
# Requirement already satisfied: screeninfo<0.7.0,>=0.6.7 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.6.7)
# Requirement already satisfied: iso8601<0.2.0,>=0.1.14 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.1.16)
# Requirement already satisfied: papermill<3.0.0,>=2.4.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.4.0)
# Requirement already satisfied: bs4<0.0.2,>=0.0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.0.1)
# Requirement already satisfied: feedparser<7.0.0,>=6.0.10 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (6.0.10)
# Requirement already satisfied: numpy==1.23.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.23.4)
# Collecting grpcio<2.0.0,>=1.51.1
#   Downloading grpcio-1.51.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 4.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: robin-stocks<3.0.0,>=2.0.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.1.0)
# Requirement already satisfied: pandas-market-calendars<3.3,>=3.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.2)
# Requirement already satisfied: pyally<2.0.0,>=1.1.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.1.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.0.9 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.0.10)
# Requirement already satisfied: python-i18n<0.4.0,>=0.3.9 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.3.9)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (5.11.0)
# Requirement already satisfied: ruamel.yaml<0.18.0,>=0.17.21 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.17.21)
# Requirement already satisfied: finvizfinance<0.15.0,>=0.14.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.14.4)
# Requirement already satisfied: charset-normalizer==2.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.1.1)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.0.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (8.0.4)
# Requirement already satisfied: GitPython<4.0.0,>=3.1.17 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.1.30)
# Requirement already satisfied: degiro-connector<3.0.0,>=2.0.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.0.21)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.6.2)
# Requirement already satisfied: ipython==8.5.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (8.5.0)
# Requirement already satisfied: Quandl<4.0.0,>=3.6.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.7.0)
# Requirement already satisfied: rapidfuzz<2.0.0,>=1.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.9.1)
# Requirement already satisfied: python-binance<2.0.0,>=1.0.15 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.0.16)
# Requirement already satisfied: jupyterlab-widgets<4.0.0,>=3.0.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.0.5)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.1.2)
# Collecting ccxt<3.0.0,>=2.5.67
#   Downloading ccxt-2.6.50-py2.py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: jupyterlab<4.0.0,>=3.2.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.5.2)
# Requirement already satisfied: pythclient<0.2.0,>=0.1.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.1.2)
# Requirement already satisfied: psaw<0.0.13,>=0.0.12 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.0.12)
# Requirement already satisfied: pandas-ta<0.4.0,>=0.3.14-beta.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.3.14b0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.16 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.0.36)
# Requirement already satisfied: oandapyV20<0.7.0,>=0.6.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.6.3)
# Requirement already satisfied: pandas<2.0.0,>=1.5.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.5.2)
# Requirement already satisfied: investpy<2.0.0,>=1.0.7 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.0.8)
# Requirement already satisfied: investiny<0.6.0,>=0.5.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.5.0)
# Requirement already satisfied: voila>=0.3.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.4.0)
# Requirement already satisfied: squarify<0.5.0,>=0.4.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.4.3)
# Requirement already satisfied: alpha-vantage<3.0.0,>=2.3.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.3.1)
# Requirement already satisfied: ascii-magic<2.0,>=1.6 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.6)
# Collecting protobuf==3.20.1
#   Using cached protobuf-3.20.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied: streamlit<2.0.0,>=1.12.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.1.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.2.1)
# Collecting yfinance==0.2.4
#   Downloading yfinance-0.2.4-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 2.4 MB/s eta 0:00:00
# Collecting thepassiveinvestor<2.0.0,>=1.0.11
#   Downloading thepassiveinvestor-1.1.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: bt<0.3.0,>=0.2.9 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.2.9)
# Requirement already satisfied: stocksera<0.2.0,>=0.1.21 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.1.21)
# Requirement already satisfied: setuptools<65.5.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (65.4.1)
# Requirement already satisfied: pytrends<5.0.0,>=4.7.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (4.8.0)
# Requirement already satisfied: sentiment-investor<3.0.0,>=2.0.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.1.0)
# Requirement already satisfied: packaging>=22.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (22.0)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.28.1)
# Requirement already satisfied: scipy<2.0.0,>=1.9.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.9.3)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (1.1)
# Requirement already satisfied: pyrsistent<0.19.0,>=0.18.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.18.1)
# Requirement already satisfied: rich<13.0.0,>=12.6.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (12.6.0)
# Requirement already satisfied: statsmodels<0.14,>=0.13 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.13.5)
# Requirement already satisfied: ipyflex<0.3.0,>=0.2.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.2.6)
# Requirement already satisfied: valinvest<0.0.3,>=0.0.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.0.2)
# Requirement already satisfied: mplfinance<0.13.0,>=0.12.7-alpha.7 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.12.9b7)
# Requirement already satisfied: watchdog<3.0.0,>=2.1.9 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.2.1)
# Requirement already satisfied: fred<4.0,>=3.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.1)
# Requirement already satisfied: finnhub-python<3.0.0,>=2.4.10 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.4.15)
# Requirement already satisfied: Pygments<3.0.0,>=2.11.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (2.14.0)
# Requirement already satisfied: seaborn<0.12.0,>=0.11.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.11.2)
# Requirement already satisfied: ipympl<0.9.0,>=0.8.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.8.4)
# Requirement already satisfied: pyEX<0.6.0,>=0.5.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (0.5.0)
# Requirement already satisfied: vaderSentiment==3.3.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openbb) (3.3.2)
# Requirement already satisfied: pickleshare in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (0.18.2)
# Requirement already satisfied: traitlets>=5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (5.8.0)
# Requirement already satisfied: decorator in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (0.1.6)
# Requirement already satisfied: stack-data in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (0.6.2)
# Requirement already satisfied: backcall in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipython==8.5.0->openbb) (0.2.0)
# Requirement already satisfied: frozendict>=2.3.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from yfinance==0.2.4->openbb) (2.3.4)
# Requirement already satisfied: pytz>=2022.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from yfinance==0.2.4->openbb) (2022.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from yfinance==0.2.4->openbb) (4.11.1)
# Requirement already satisfied: multitasking>=0.0.7 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from yfinance==0.2.4->openbb) (0.0.11)
# Requirement already satisfied: cryptography>=3.3.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from yfinance==0.2.4->openbb) (39.0.0)
# Requirement already satisfied: appdirs>=1.4.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from yfinance==0.2.4->openbb) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from yfinance==0.2.4->openbb) (4.9.2)
# Requirement already satisfied: aiohttp in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from alpha-vantage<3.0.0,>=2.3.1->openbb) (3.8.3)
# Requirement already satisfied: colorama in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ascii-magic<2.0,>=1.6->openbb) (0.4.6)
# Requirement already satisfied: Pillow in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ascii-magic<2.0,>=1.6->openbb) (9.4.0)
# Requirement already satisfied: ffn>=0.3.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from bt<0.3.0,>=0.2.9->openbb) (0.3.6)
# Requirement already satisfied: pyprind>=2.11 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from bt<0.3.0,>=0.2.9->openbb) (2.11.3)
# Requirement already satisfied: certifi>=2018.1.18 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ccxt<3.0.0,>=2.5.67->openbb) (2022.12.7)
# Requirement already satisfied: aiodns>=1.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ccxt<3.0.0,>=2.5.67->openbb) (3.0.0)
# Requirement already satisfied: yarl>=1.7.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ccxt<3.0.0,>=2.5.67->openbb) (1.8.2)
# Requirement already satisfied: onetimepass<2.0.0,>=1.0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from degiro-connector<3.0.0,>=2.0.3->openbb) (1.0.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.12.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from degiro-connector<3.0.0,>=2.0.3->openbb) (1.14.1)
# Requirement already satisfied: sgmllib3k in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from feedparser<7.0.0,>=6.0.10->openbb) (1.0.0)
# Requirement already satisfied: tqdm in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from finviz<2.0.0,>=1.3.4->openbb) (4.64.1)
# Requirement already satisfied: tenacity in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from finviz<2.0.0,>=1.3.4->openbb) (8.1.0)
# Requirement already satisfied: urllib3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from finviz<2.0.0,>=1.3.4->openbb) (1.26.13)
# Requirement already satisfied: cssselect in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from finviz<2.0.0,>=1.3.4->openbb) (1.2.0)
# Requirement already satisfied: user-agent in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from finviz<2.0.0,>=1.3.4->openbb) (0.1.10)
# Requirement already satisfied: datetime in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from finvizfinance<0.15.0,>=0.14.0->openbb) (4.9)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from GitPython<4.0.0,>=3.1.17->openbb) (4.0.10)
# Requirement already satisfied: convertdate>=2.3.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from holidays<0.15.0,>=0.14.2->openbb) (2.4.0)
# Requirement already satisfied: korean-lunar-calendar in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from holidays<0.15.0,>=0.14.2->openbb) (0.3.1)
# Requirement already satisfied: python-dateutil in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from holidays<0.15.0,>=0.14.2->openbb) (2.8.2)
# Requirement already satisfied: hijri-converter in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from holidays<0.15.0,>=0.14.2->openbb) (2.2.4)
# Requirement already satisfied: six>=1.9 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from html5lib<2.0,>=1.1->openbb) (1.16.0)
# Requirement already satisfied: webencodings in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from html5lib<2.0,>=1.1->openbb) (0.5.1)
# Requirement already satisfied: httpx<0.24.0,>=0.23.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from investiny<0.6.0,>=0.5.0->openbb) (0.23.2)
# Requirement already satisfied: Unidecode>=1.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from investpy<2.0.0,>=1.0.7->openbb) (1.3.6)
# Requirement already satisfied: ipykernel>=4.7 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipympl<0.9.0,>=0.8.2->openbb) (6.19.4)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipywidgets<9.0.0,>=8.0.2->openbb) (4.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from Jinja2<4.0.0,>=3.0.3->openbb) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jsonschema<4.0.0,>=3.2.0->openbb) (22.2.0)
# Requirement already satisfied: notebook<7 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (6.5.2)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (1.23.4)
# Requirement already satisfied: jupyter-core in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (5.1.1)
# Requirement already satisfied: jupyterlab-server~=2.10 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (2.16.6)
# Requirement already satisfied: tomli in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (2.0.1)
# Requirement already satisfied: nbclassic in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (0.4.8)
# Requirement already satisfied: tornado>=6.1.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (6.2)
# Requirement already satisfied: mypy-extensions>=0.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from linearmodels<5.0,>=4.25->openbb) (0.4.3)
# Requirement already satisfied: Cython>=0.29.21 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from linearmodels<5.0,>=4.25->openbb) (0.29.32)
# Requirement already satisfied: property-cached>=1.6.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from linearmodels<5.0,>=4.25->openbb) (1.6.4)
# Requirement already satisfied: setuptools-scm<7.0.0,>=6.4.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from linearmodels<5.0,>=4.25->openbb) (6.4.2)
# Requirement already satisfied: pyhdfe>=0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from linearmodels<5.0,>=4.25->openbb) (0.1.1)
# Requirement already satisfied: formulaic~=0.3.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from linearmodels<5.0,>=4.25->openbb) (0.3.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (1.4.4)
# Requirement already satisfied: et-xmlfile in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from openpyxl<4.0.0,>=3.0.9->openbb) (1.1.0)
# Requirement already satisfied: exchange-calendars>=3.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pandas-market-calendars<3.3,>=3.2->openbb) (4.2.4)
# Requirement already satisfied: nbformat>=5.1.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from papermill<3.0.0,>=2.4.0->openbb) (5.7.1)
# Requirement already satisfied: click in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from papermill<3.0.0,>=2.4.0->openbb) (8.1.3)
# Requirement already satisfied: nbclient>=0.2.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from papermill<3.0.0,>=2.4.0->openbb) (0.7.2)
# Requirement already satisfied: ansiwrap in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from papermill<3.0.0,>=2.4.0->openbb) (0.8.4)
# Requirement already satisfied: entrypoints in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from papermill<3.0.0,>=2.4.0->openbb) (0.4)
# Requirement already satisfied: pyyaml in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from papermill<3.0.0,>=2.4.0->openbb) (6.0)
# Requirement already satisfied: update-checker>=0.18 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from praw<8.0.0,>=7.1.4->openbb) (0.18.0)
# Requirement already satisfied: websocket-client>=0.54.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from praw<8.0.0,>=7.1.4->openbb) (1.4.2)
# Requirement already satisfied: prawcore<3,>=2.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from praw<8.0.0,>=7.1.4->openbb) (2.3.0)
# Requirement already satisfied: wcwidth in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from prompt-toolkit<4.0.0,>=3.0.16->openbb) (0.2.5)
# Requirement already satisfied: requests-oauthlib in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pyally<2.0.0,>=1.1.2->openbb) (1.3.1)
# Requirement already satisfied: deprecation>=2.0.6 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pyEX<0.6.0,>=0.5.0->openbb) (2.1.0)
# Requirement already satisfied: socketIO-client-nexus>=0.7.6 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pyEX<0.6.0,>=0.5.0->openbb) (0.7.6)
# Requirement already satisfied: sseclient>=0.0.22 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pyEX<0.6.0,>=0.5.0->openbb) (0.0.27)
# Requirement already satisfied: temporal-cache>=0.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pyEX<0.6.0,>=0.5.0->openbb) (0.1.4)
# Requirement already satisfied: flake8 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pythclient<0.2.0,>=0.1.2->openbb) (6.0.0)
# Requirement already satisfied: typing-extensions in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pythclient<0.2.0,>=0.1.2->openbb) (4.4.0)
# Requirement already satisfied: backoff in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pythclient<0.2.0,>=0.1.2->openbb) (2.2.1)
# Requirement already satisfied: base58 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pythclient<0.2.0,>=0.1.2->openbb) (2.1.1)
# Requirement already satisfied: loguru in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pythclient<0.2.0,>=0.1.2->openbb) (0.6.0)
# Requirement already satisfied: dateparser in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from python-binance<2.0.0,>=1.0.15->openbb) (1.1.5)
# Requirement already satisfied: ujson in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from python-binance<2.0.0,>=1.0.15->openbb) (5.6.0)
# Requirement already satisfied: websockets in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from python-binance<2.0.0,>=1.0.15->openbb) (10.4)
# Requirement already satisfied: more-itertools in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from Quandl<4.0.0,>=3.6.0->openbb) (9.0.0)
# Requirement already satisfied: inflection>=0.3.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from Quandl<4.0.0,>=3.6.0->openbb) (0.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from requests<3.0.0,>=2.25.1->openbb) (3.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from rich<13.0.0,>=12.6.0->openbb) (0.9.1)
# Requirement already satisfied: pyotp in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from robin-stocks<3.0.0,>=2.0.3->openbb) (2.8.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ruamel.yaml<0.18.0,>=0.17.21->openbb) (0.2.7)
# Requirement already satisfied: beartype<0.8.0,>=0.7.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from sentiment-investor<3.0.0,>=2.0.0->openbb) (0.7.1)
# Requirement already satisfied: patsy>=0.5.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from statsmodels<0.14,>=0.13->openbb) (0.5.3)
# Requirement already satisfied: validators>=0.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (0.20.0)
# Requirement already satisfied: altair>=3.2.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (4.2.0)
# Requirement already satisfied: pympler>=0.9 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (1.0.1)
# Requirement already satisfied: toml in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (0.10.2)
# Requirement already satisfied: pyarrow>=4.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (10.0.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (6.0.0)
# Requirement already satisfied: tzlocal>=1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (4.2)
# Requirement already satisfied: cachetools>=4.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (5.2.0)
# Requirement already satisfied: blinker>=1.0.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (1.5)
# Requirement already satisfied: semver in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (2.13.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from streamlit<2.0.0,>=1.12.2->openbb) (0.8.0)
# Requirement already satisfied: jupyter-client<=7.4.1,>=6.1.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from voila>=0.3.0->openbb) (7.4.1)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from voila>=0.3.0->openbb) (7.2.7)
# Requirement already satisfied: pycares>=4.0.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from aiodns>=1.1.1->ccxt<3.0.0,>=2.5.67->openbb) (4.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (1.3.1)
# Requirement already satisfied: toolz in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from altair>=3.2.0->streamlit<2.0.0,>=1.12.2->openbb) (0.12.0)
# Requirement already satisfied: soupsieve>1.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.4->openbb) (2.3.2.post1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from convertdate>=2.3.0->holidays<0.15.0,>=0.14.2->openbb) (0.5.12)
# Requirement already satisfied: cffi>=1.12 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from cryptography>=3.3.2->yfinance==0.2.4->openbb) (1.15.1)
# Requirement already satisfied: pyluach in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from exchange-calendars>=3.3->pandas-market-calendars<3.3,>=3.2->openbb) (2.0.2)
# Requirement already satisfied: tabulate>=0.7.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (0.9.0)
# Requirement already satisfied: future>=0.15 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (0.18.2)
# Requirement already satisfied: scikit-learn>=0.15 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (1.2.0)
# Requirement already satisfied: pandas-datareader>=0.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (0.10.0)
# Requirement already satisfied: interface-meta<2.0.0,>=1.2.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from formulaic~=0.3.2->linearmodels<5.0,>=4.25->openbb) (1.3.0)
# Requirement already satisfied: astor>=0.8 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from formulaic~=0.3.2->linearmodels<5.0,>=4.25->openbb) (0.8.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython<4.0.0,>=3.1.17->openbb) (5.0.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from httpx<0.24.0,>=0.23.0->investiny<0.6.0,>=0.5.0->openbb) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from httpx<0.24.0,>=0.23.0->investiny<0.6.0,>=0.5.0->openbb) (1.5.0)
# Requirement already satisfied: sniffio in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from httpx<0.24.0,>=0.23.0->investiny<0.6.0,>=0.5.0->openbb) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from importlib-metadata>=1.4->streamlit<2.0.0,>=1.12.2->openbb) (3.11.0)
# Requirement already satisfied: comm>=0.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipykernel>=4.7->ipympl<0.9.0,>=0.8.2->openbb) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipykernel>=4.7->ipympl<0.9.0,>=0.8.2->openbb) (1.6.4)
# Requirement already satisfied: nest-asyncio in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipykernel>=4.7->ipympl<0.9.0,>=0.8.2->openbb) (1.5.6)
# Requirement already satisfied: psutil in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipykernel>=4.7->ipympl<0.9.0,>=0.8.2->openbb) (5.9.4)
# Requirement already satisfied: pyzmq>=17 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ipykernel>=4.7->ipympl<0.9.0,>=0.8.2->openbb) (24.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jedi>=0.16->ipython==8.5.0->openbb) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyter-core->jupyterlab<4.0.0,>=3.2.4->openbb) (2.6.2)
# Requirement already satisfied: Send2Trash in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.17.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (3.6.2)
# Requirement already satisfied: prometheus-client in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.15.0)
# Requirement already satisfied: argon2-cffi in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (21.3.0)
# Requirement already satisfied: babel>=2.10 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab<4.0.0,>=3.2.4->openbb) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from jupyterlab-server~=2.10->jupyterlab<4.0.0,>=3.2.4->openbb) (0.9.10)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (1.5.0)
# Requirement already satisfied: bleach in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (5.0.1)
# Requirement already satisfied: defusedxml in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (0.2.2)
# Requirement already satisfied: tinycss2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (1.2.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (2.0.4)
# Requirement already satisfied: fastjsonschema in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbformat>=5.1.2->papermill<3.0.0,>=2.4.0->openbb) (2.16.2)
# Requirement already satisfied: ipython-genutils in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from notebook<7->jupyterlab<4.0.0,>=3.2.4->openbb) (0.2.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from nbclassic->jupyterlab<4.0.0,>=3.2.4->openbb) (0.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pexpect>4.3->ipython==8.5.0->openbb) (0.7.0)
# Requirement already satisfied: pytz-deprecation-shim in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from tzlocal>=1.1->streamlit<2.0.0,>=1.12.2->openbb) (0.1.0.post0)
# Requirement already satisfied: textwrap3>=0.9.2 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from ansiwrap->papermill<3.0.0,>=2.4.0->openbb) (0.9.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from dateparser->python-binance<2.0.0,>=1.0.15->openbb) (2022.10.31)
# Requirement already satisfied: zope.interface in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from datetime->finvizfinance<0.15.0,>=0.14.0->openbb) (5.5.2)
# Requirement already satisfied: pycodestyle<2.11.0,>=2.10.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from flake8->pythclient<0.2.0,>=0.1.2->openbb) (2.10.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from flake8->pythclient<0.2.0,>=0.1.2->openbb) (0.7.0)
# Requirement already satisfied: pyflakes<3.1.0,>=3.0.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from flake8->pythclient<0.2.0,>=0.1.2->openbb) (3.0.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from requests-oauthlib->pyally<2.0.0,>=1.1.2->openbb) (3.2.2)
# Requirement already satisfied: pure-eval in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from stack-data->ipython==8.5.0->openbb) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from stack-data->ipython==8.5.0->openbb) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from stack-data->ipython==8.5.0->openbb) (1.2.0)
# Requirement already satisfied: pycparser in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance==0.2.4->openbb) (2.21)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->investiny<0.6.0,>=0.5.0->openbb) (0.14.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from scikit-learn>=0.15->ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from scikit-learn>=0.15->ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (3.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (21.2.0)
# Requirement already satisfied: tzdata in /home/sysak_ma/miniconda3/envs/obb/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit<2.0.0,>=1.12.2->openbb) (2022.7)
# Installing collected packages: thepassiveinvestor, protobuf, grpcio, yfinance, ccxt, openbb
#   Attempting uninstall: thepassiveinvestor
#     Found existing installation: thepassiveinvestor 1.0.10
#     Uninstalling thepassiveinvestor-1.0.10:
#       Successfully uninstalled thepassiveinvestor-1.0.10
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.50.0
#     Uninstalling grpcio-1.50.0:
#       Successfully uninstalled grpcio-1.50.0
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.1.96
#     Uninstalling yfinance-0.1.96:
#       Successfully uninstalled yfinance-0.1.96
#   Attempting uninstall: ccxt
#     Found existing installation: ccxt 1.95.43
#     Uninstalling ccxt-1.95.43:
#       Successfully uninstalled ccxt-1.95.43
#   Attempting uninstall: openbb
#     Found existing installation: openbb 2.1.0
#     Uninstalling openbb-2.1.0:
#       Successfully uninstalled openbb-2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tinkoff-investments 0.2.0b45 requires protobuf<4.0.0,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# Successfully installed ccxt-2.6.50 grpcio-1.51.1 openbb-2.2.0 protobuf-3.20.1 thepassiveinvestor-1.1.2 yfinance-0.2.4

# %%
from IPython.display import display
from openbb_terminal.sdk import openbb
from PIL import Image

import datetime
import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np
import pandas as pd
import seaborn as sns
import tqdm

import investpack

# %%
hk8_tickers = """HKG:0001
HKG:0175
HKG:2020
HKG:2269
HKG:2628
HKG:0288
HKG:0291
HKG:3888"""
b = investpack.draw_rsi(hk8_tickers, (12, 5))
Image.open(b)
# Out:
# 2023-01-20 21:13:27.466 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:27.467 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0001.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:27.937 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:27.940 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:27.942 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0001.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:28.299 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:28.311 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:28.312 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0001.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:28.312 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:29.150 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:29.151 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:29.175 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:29.176 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0175.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:29.535 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:29.538 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:29.540 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0175.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:29.870 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:29.881 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:29.882 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0175.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:29.883 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:30.527 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:30.528 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:30.552 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:30.553 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2020.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:32.372 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:32.374 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:32.375 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2020.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:32.722 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:32.731 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:32.732 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "2020.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:32.733 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:33.377 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:33.378 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:33.407 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:33.408 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2269.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:33.748 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:33.750 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:33.751 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2269.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:34.101 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:34.110 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:34.111 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "2269.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:34.112 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# No dividends found.
# 2023-01-20 21:13:34.579 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:34.579 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:34.586 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:34.588 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2628.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:34.997 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:35.000 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:35.001 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2628.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:35.363 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:35.374 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:35.375 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "2628.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:35.375 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:36.016 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:36.017 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:36.039 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:36.040 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0288.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:36.381 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:36.383 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:36.384 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0288.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:36.730 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:36.746 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:36.748 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0288.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:36.749 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:37.283 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:37.283 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:37.310 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:37.311 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0291.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:37.674 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:37.678 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:37.679 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0291.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:38.017 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:38.026 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:38.027 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0291.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:38.029 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:38.740 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:38.741 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:38.764 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:38.765 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "3888.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:39.140 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:39.143 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:13:39.146 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "3888.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:13:39.509 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:13:39.518 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:39.519 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "3888.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:13:39.520 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:13:40.179 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:13:40.180 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2093x912>

# %%
green_tickers = """HKG:0388
HKG:3988
HKG:2331
HKG:0669
HKG:9988
HKG:2015
HKG:0857
HKG:0386
HKG:1088
HKG:1347
HKG:9999
HKG:1928
HKG:1109"""

blue_tickers = """HKG:0939
HKG:9866
HKG:9618
HKG:2688
HKG:0992
HKG:0268
HKG:2518
HKG:9888
HKG:9626
HKG:0700
HKG:1113"""

b = investpack.draw_rsi(green_tickers + '\n' + blue_tickers, (12, 10))
Image.open(b)
# Out:
# 2023-01-20 21:15:12.057 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:12.058 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0388.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:12.412 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:12.415 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:12.416 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0388.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:12.778 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:12.790 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:12.791 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0388.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:12.792 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:14.254 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:14.255 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:14.274 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:14.275 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "3988.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:14.656 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:14.658 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:14.660 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "3988.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:15.072 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:15.085 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:15.086 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "3988.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:15.087 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:15.719 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:15.720 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:15.736 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:15.737 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2331.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:16.099 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:16.103 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:16.105 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2331.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:16.482 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:16.497 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:16.498 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "2331.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:16.500 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:17.252 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:17.253 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:17.267 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:17.268 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0669.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:17.606 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:17.608 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:17.610 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0669.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:17.969 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:17.982 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:17.983 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0669.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:17.984 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:18.614 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:18.615 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:18.633 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:18.633 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9988.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:19.000 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:19.002 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:19.004 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9988.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:19.384 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:19.396 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:19.398 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "9988.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:19.399 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# No dividends found.
# 2023-01-20 21:15:19.833 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:19.834 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:19.838 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:19.839 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2015.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:20.177 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:20.179 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:20.180 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2015.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:20.531 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:20.541 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:20.542 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "2015.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:20.543 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# No dividends found.
# 2023-01-20 21:15:20.892 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:20.893 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:20.897 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:20.898 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0857.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:21.316 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:21.319 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:21.320 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0857.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:21.671 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:21.681 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:21.682 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0857.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:21.682 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:22.352 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:22.353 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:22.371 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:22.372 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0386.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:22.748 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:22.753 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:22.757 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0386.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:23.111 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:23.121 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:23.122 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0386.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:23.123 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:23.794 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:23.794 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:23.814 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:23.816 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1088.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:24.193 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:24.194 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:24.195 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1088.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:24.503 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:24.527 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:24.529 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "1088.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:24.531 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:25.177 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:25.178 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:25.193 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:25.194 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1347.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:25.537 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:25.543 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:25.546 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1347.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:25.923 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:25.934 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:25.935 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "1347.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:25.936 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:26.460 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:26.461 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:26.472 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:26.473 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9999.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:27.032 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:27.034 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:27.035 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9999.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:28.455 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:28.466 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:28.466 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "9999.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:28.467 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:28.921 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:28.922 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:28.947 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:28.948 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1928.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:29.292 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:29.295 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:29.296 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1928.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:29.657 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:29.670 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:29.670 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "1928.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:29.671 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:30.197 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:30.197 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:30.207 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:30.208 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1109.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:30.639 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:30.641 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:30.642 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1109.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:30.994 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:31.003 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:31.004 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "1109.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:31.005 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:31.662 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:31.663 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:31.679 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:31.679 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0939.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:32.006 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:32.008 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:32.009 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0939.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:32.369 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:32.380 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:32.381 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0939.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:32.382 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:33.019 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:33.019 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:33.034 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:33.035 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9866.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:33.364 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:33.367 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:33.368 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9866.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:33.736 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:33.745 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:33.746 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "9866.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:33.747 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# No dividends found.
# 2023-01-20 21:15:34.082 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:34.083 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:34.087 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:34.088 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9618.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:34.413 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:34.415 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:34.416 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9618.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:34.754 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:34.761 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:34.763 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "9618.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:34.763 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:35.193 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:35.194 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:35.213 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:35.214 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2688.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:35.604 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:35.606 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:35.607 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2688.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:35.949 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:35.957 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:35.958 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "2688.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:35.958 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:36.624 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:36.625 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:36.643 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:36.644 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0992.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:37.021 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:37.023 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:37.024 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0992.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:37.367 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:37.376 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:37.377 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0992.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:37.378 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:38.272 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:38.273 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:38.290 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:38.290 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0268.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:38.618 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:38.619 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:38.620 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0268.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:39.017 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:39.033 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:39.035 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0268.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:39.036 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:39.744 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:39.744 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:39.756 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:39.757 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2518.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:40.107 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:40.109 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:40.110 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "2518.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:40.468 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:40.479 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:40.481 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "2518.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:40.483 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:41.035 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:41.036 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:41.050 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:41.051 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9888.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:41.395 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:41.398 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:41.399 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9888.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:41.787 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:41.799 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:41.800 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "9888.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:41.801 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# No dividends found.
# 2023-01-20 21:15:42.203 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:42.204 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:42.209 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:42.210 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9626.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:42.546 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:42.549 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:42.550 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "9626.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:42.927 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:42.939 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:42.941 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "9626.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:42.943 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# No dividends found.
# 2023-01-20 21:15:43.327 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:43.328 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:43.332 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:43.334 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0700.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:43.689 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:43.692 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:43.696 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "0700.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:44.071 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:44.079 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:44.080 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "0700.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:44.081 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:44.746 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:44.747 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:44.762 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:44.763 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2022-01-20 00:00:00", "interval": "1440", "end_date": "None", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1113.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:45.132 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:45.133 INFO    openbb_terminal.stocks.stocks_helper: START
# 2023-01-20 21:15:45.134 INFO    openbb_terminal.stocks.stocks_helper: {"INPUT": {"start_date": "2023-01-19 00:00:00", "interval": "1", "end_date": "2023-01-20 00:00:00", "prepost": "False", "source": "YahooFinance", "iexrange": "ytd", "weekly": "False", "monthly": "False", "verbose": "False", "symbol": "1113.HK"}, "VIRTUAL_PATH": "stocks.load", "CHART": false}
# 2023-01-20 21:15:45.490 INFO    openbb_terminal.stocks.stocks_helper: END
# 2023-01-20 21:15:45.498 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:45.499 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: {"INPUT": {"symbol": "1113.HK"}, "VIRTUAL_PATH": "stocks.fa.divs", "CHART": false}
# 2023-01-20 21:15:45.500 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: START
# 2023-01-20 21:15:46.032 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# 2023-01-20 21:15:46.033 INFO    openbb_terminal.stocks.fundamental_analysis.yahoo_finance_model: END
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2093x1682>

# %%
b = investpack.draw_rsi(green_tickers + '\n' + blue_tickers)
i = Image.open(b)
i
# Out:
# No dividends found.
# No dividends found.
# No dividends found.
# No dividends found.
# No dividends found.

# %%
rsi_data = {}
for ticker in tqdm.tqdm((green_tickers + '\n' + blue_tickers).split('\n')):
    data = investpack.get_daily_data_with_today(ticker, datetime.datetime.combine(datetime.date.today(), datetime.time()), enforce_today=True)
    rsi_data[ticker] = investpack.RSI(data)
rsi_data = pd.DataFrame(rsi_data)
rsi_data.index = [str(x)[-5:].replace('-', '/') for x in rsi_data.index.date]
rsi_data.columns = [x[4:] for x in rsi_data.columns]

plt.figure(figsize=(10, 7))
ax = sns.heatmap(rsi_data.T.iloc[:, -14:].sort_values(rsi_data.index[-1], ascending=False), annot=True, cbar=False)
ax.tick_params(left=True, labelleft=True, right=True, labelright=True, rotation=0)
plt.title('RSI')
plt.show()
# Out:
#  17%|███████▎                                    | 4/24 [00:10<00:50,  2.51s/it]
# No dividends found.
#  21%|█████████▏                                  | 5/24 [00:12<00:45,  2.40s/it]
# No dividends found.
#  58%|█████████████████████████                  | 14/24 [00:51<00:33,  3.32s/it]
# No dividends found.
#  83%|███████████████████████████████████▊       | 20/24 [01:08<00:11,  2.86s/it]
# No dividends found.
#  88%|█████████████████████████████████████▋     | 21/24 [01:10<00:07,  2.61s/it]
# No dividends found.
# 100%|███████████████████████████████████████████| 24/24 [01:19<00:00,  3.29s/it]

# %%
g8_tickers = """HKG:0001
HKG:0175
HKG:2020
HKG:2269
HKG:2628
HKG:0288
HKG:0291
HKG:3888"""

# %%
rsi_data = {}
for ticker in tqdm.tqdm((g8_tickers).split('\n')):
    data = get_daily_data_with_today(ticker, datetime.datetime.combine(datetime.date.today(), datetime.time()), enforce_today=True)
    rsi_data[ticker] = RSI(data)
rsi_data = pd.DataFrame(rsi_data)
rsi_data.index = [str(x)[-5:].replace('-', '/') for x in rsi_data.index.date]
rsi_data.columns = [x[4:] for x in rsi_data.columns]

plt.figure(figsize=(10, 4))
ax = sns.heatmap(rsi_data.T.iloc[:, -14:].sort_values(rsi_data.index[-1], ascending=False), annot=True, cbar=False)
ax.tick_params(left=True, labelleft=True, right=True, labelright=True, rotation=0)
plt.title('RSI')
plt.show()
# Out:
#  38%|████████████████▉                            | 3/8 [00:07<00:12,  2.48s/it]
# No dividends found.
# 100%|█████████████████████████████████████████████| 8/8 [00:23<00:00,  3.00s/it]

# %%
for ticker in tqdm.tqdm((green_tickers + '\n' + blue_tickers).split('\n')):
    df = openbb.stocks.fa.divs(ticker_to_yahoo_format(ticker))
    print(ticker)
    if df.empty:
        continue
    display(df[df.index.tz_localize(None) > datetime.datetime.now() - datetime.timedelta(days=365)])
# Out:
#   0%|                                                    | 0/24 [00:00<?, ?it/s]
# HKG:0388
#                            Dividends  Change
# Date
# 2022-08-30 00:00:00+08:00       3.45   -0.73
# 2022-03-09 00:00:00+08:00       4.18   -0.51
#   4%|█▊                                          | 1/24 [00:01<00:23,  1.04s/it]
# HKG:3988
#                            Dividends    Change
# Date
# 2022-07-07 00:00:00+08:00   0.258911  0.021268
#   8%|███▋                                        | 2/24 [00:01<00:21,  1.02it/s]
# HKG:2331
#                            Dividends  Change
# Date
# 2022-06-17 00:00:00+08:00     0.5345  0.2859
#  12%|█████▌                                      | 3/24 [00:02<00:20,  1.02it/s]
# HKG:0669
#                            Dividends  Change
# Date
# 2022-08-30 00:00:00+08:00       0.95   -0.05
# 2022-05-18 00:00:00+08:00       1.00    0.15
#  17%|███████▎                                    | 4/24 [00:03<00:19,  1.04it/s]
# No dividends found.
#  21%|█████████▏                                  | 5/24 [00:04<00:16,  1.13it/s]
# HKG:9988
# No dividends found.
#  25%|███████████                                 | 6/24 [00:05<00:14,  1.23it/s]
# HKG:2015
# HKG:0857
#                            Dividends   Change
# Date
# 2022-09-09 00:00:00+08:00    0.23338  0.12027
# 2022-06-20 00:00:00+08:00    0.11311 -0.04342
#  29%|████████████▊                               | 7/24 [00:06<00:14,  1.15it/s]
# HKG:0386
#                            Dividends    Change
# Date
# 2022-09-08 00:00:00+08:00     0.1851 -0.176500
# 2022-05-31 00:00:00+08:00     0.3616  0.169429
#  33%|██████████████▋                             | 8/24 [00:07<00:14,  1.10it/s]
# HKG:1088
#                            Dividends    Change
# Date
# 2022-06-29 00:00:00+08:00      3.125  0.967721
#  38%|████████████████▌                           | 9/24 [00:08<00:13,  1.09it/s]
# HKG:1347
# Empty DataFrame
# Columns: [Dividends, Change]
# Index: []
#  42%|█████████████████▉                         | 10/24 [00:09<00:12,  1.12it/s]
# HKG:9999
#                            Dividends  Change
# Date
# 2022-12-01 00:00:00+08:00     0.0870  0.0150
# 2022-08-31 00:00:00+08:00     0.0720  0.0076
# 2022-06-07 00:00:00+08:00     0.0644 -0.0166
# 2022-03-10 00:00:00+08:00     0.0810  0.0360
#  46%|███████████████████▋                       | 11/24 [00:09<00:10,  1.18it/s]
# HKG:1928
# Empty DataFrame
# Columns: [Dividends, Change]
# Index: []
#  50%|█████████████████████▌                     | 12/24 [00:10<00:10,  1.19it/s]
# HKG:1109
#                            Dividends  Change
# Date
# 2022-09-14 00:00:00+08:00      0.208  -1.276
# 2022-06-20 00:00:00+08:00      1.484   1.276
#  54%|███████████████████████▎                   | 13/24 [00:11<00:09,  1.13it/s]
# HKG:0939
#                            Dividends    Change
# Date
# 2022-06-29 00:00:00+08:00    0.42595  0.035115
#  58%|█████████████████████████                  | 14/24 [00:12<00:09,  1.09it/s]
# No dividends found.
#  62%|██████████████████████████▉                | 15/24 [00:13<00:07,  1.20it/s]
# HKG:9866
# HKG:9618
#                            Dividends  Change
# Date
# 2022-05-19 00:00:00+08:00     4.9451     NaN
#  67%|████████████████████████████▋              | 16/24 [00:13<00:06,  1.26it/s]
# HKG:2688
#                            Dividends  Change
# Date
# 2022-11-03 00:00:00+08:00       0.64   -1.47
# 2022-05-23 00:00:00+08:00       2.11    1.52
#  71%|██████████████████████████████▍            | 17/24 [00:14<00:05,  1.18it/s]
# HKG:0992
#                            Dividends  Change
# Date
# 2022-11-25 00:00:00+08:00       0.08   -0.22
# 2022-08-01 00:00:00+08:00       0.30    0.22
#  75%|████████████████████████████████▎          | 18/24 [00:15<00:05,  1.12it/s]
# HKG:0268
# Empty DataFrame
# Columns: [Dividends, Change]
# Index: []
#  79%|██████████████████████████████████         | 19/24 [00:16<00:04,  1.11it/s]
# HKG:2518
#                            Dividends  Change
# Date
# 2022-03-18 00:00:00+08:00     0.1325     NaN
#  83%|███████████████████████████████████▊       | 20/24 [00:17<00:03,  1.11it/s]
# No dividends found.
#  88%|█████████████████████████████████████▋     | 21/24 [00:18<00:02,  1.20it/s]
# HKG:9888
# No dividends found.
#  92%|███████████████████████████████████████▍   | 22/24 [00:19<00:01,  1.09it/s]
# HKG:9626
# HKG:0700
#                            Dividends  Change
# Date
# 2022-05-20 00:00:00+08:00        1.6     0.0
#  96%|█████████████████████████████████████████▏ | 23/24 [00:20<00:00,  1.08it/s]
# HKG:1113
#                            Dividends  Change
# Date
# 2022-09-05 00:00:00+08:00       0.43   -1.36
# 2022-05-24 00:00:00+08:00       1.79    1.38
# 100%|███████████████████████████████████████████| 24/24 [00:21<00:00,  1.13it/s]

# %%
today = datetime.datetime.combine(datetime.date.today(), datetime.time())
start_date = today - (datetime.timedelta(days=365))
ticker = 'YNDX'
data_until_today = openbb.stocks.load(
    ticker,
    interval=1440,
    start_date=start_date,
    source='EODHD',
    verbose=False
).drop('Adj Close', axis=1)
data_until_today
# Out:
# Invalid API Key for eodhistoricaldata
# Get your Key here: https://eodhistoricaldata.com/r/?ref=869U7F4J
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [12], line 4
#       2 start_date = today - (datetime.timedelta(days=365))
#       3 ticker = 'YNDX'
# ----> 4 data_until_today = openbb.stocks.load(
#       5     ticker,
#       6     interval=1440,
#       7     start_date=start_date,
#       8     source='EODHD',
#       9     verbose=False
#      10 ).drop('Adj Close', axis=1)
#      11 data_until_today
#
# File ~/miniconda3/envs/obb/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/obb/lib/python3.9/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~/miniconda3/envs/obb/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/obb/lib/python3.9/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/miniconda3/envs/obb/lib/python3.9/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/miniconda3/envs/obb/lib/python3.9/site-packages/pandas/core/indexes/base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['Adj Close'] not found in axis"
